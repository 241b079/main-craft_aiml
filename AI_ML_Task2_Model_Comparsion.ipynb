# %% [markdown]
# # AI & ML Task 2
# Template Notebook (No Solution)

# %% [markdown]
# ## 1. Import Libraries

# %%
# Write your imports here

# %% [markdown]
# ## 2. Load California Housing Dataset

# %%
# Load dataset

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %%
# Perform EDA

# %% [markdown]
# ## 4. Feature Scaling

# %%
# Apply StandardScaler

# %% [markdown]
# ## 5. Train Models

# %%
# Linear Regression
# Ridge Regression
# Decision Tree Regressor

# %% [markdown]
# ## 6. Evaluate Models

# %%
# Calculate RMSE and R²

# %% [markdown]
# ## 7. Compare Results

# %%
# Create comparison table

# %% [markdown]
# ## 8. Plot Actual vs Predicted

# %%
# Create graphs

# %% [markdown]
# ## 9. Conclusion

# %%
# Write your conclusion
